# %%
# Re-create the game engine 
test_case_1 = {'m': 1,q  'l0': '..............................', 'v': 1, }
# Create a simulation
test_case_1 = {'m': 1, 'l0': '...0...0...', 'v': 1, }


initial_state = { 'm': 1, 'v': 1, 'turn': 0, 'x': 0, 'is_jumping': False, 'speed': 0, 
                 'is_alive': True,  "lane": '....0.', 
                 "moto_lane" : None, "survived": False,'end_of_lane': False
                }


# TODO - Create a pydantic typed state object
def update_state(state, action):
    state['turn'] += 1
    
    updated_x = state['x'] + state['speed']
    
    if updated_x > len(state['lane']):
        interval = state['lane'][state['x']:]
        state['end_of_lane'] = True 
    else:
        interval  = state['lane'][state['x']:updated_x + 1]

    if not state['is_jumping'] and '0' in interval:
        state['is_alive'] = False
        print("Motorcycle DIED")

    if state['is_alive'] and state['end_of_lane']:
        print("Motorcycle MADE IT")

    # Update the x position
    state['x'] += state['speed']

    
    state['moto_lane'] = state['lane'][:state['x']] + '🏍️' + state['lane'][state['x']+1:]
    
    state['is_jumping'] = False
    # Take Action 
    match action:
        case 'JUMP':
            state['is_jumping'] = True
        case 'SPEED':
            state['speed'] += 1
        case 'SLOW':
            if state['speed'] > 0:
                state['speed'] -= 1
        case 'WAIT':
            pass

    return state

# %%
actions = ['SPEED', 'JUMP', 'SLOW', 'WAIT']

initial_state = { 'm': 1, 'v': 1, 'turn': 0, 'x': 0, 'is_jumping': False, 'speed': 0, 
                 'is_alive': True,  "lane": '....0.', 
                 "moto_lane" : None, "survived": False,'end_of_lane': False
                }


def findValidSequences(initial_state):
    valid_sequences_of_actions = [] 
    
    def update_state(state, action):
        state['turn'] += 1

        updated_x = state['x'] + state['speed']

        if updated_x > len(state['lane']):
            interval = state['lane'][state['x']:]
            state['end_of_lane'] = True 
        else:
            interval  = state['lane'][state['x']:updated_x + 1]

        # Case Motorcycle died
        if not state['is_jumping'] and '0' in interval:
            state['is_alive'] = False
            state['m'] -= 1
 
        
        # Case: Motorcycle made it
        if state['is_alive'] and state['end_of_lane']:
            print("MOTORCYCLE MADE IT")
            return state

        # Update the x position
        state['x'] += state['speed']


        state['moto_lane'] = state['lane'][:state['x']] + '🏍️' + state['lane'][state['x']+1:]

        state['is_jumping'] = False

        match action:
            case 'JUMP':
                state['is_jumping'] = True
            case 'SPEED':
                state['speed'] += 1
            case 'SLOW':
                if state['speed'] > 0:
                    state['speed'] -= 1
            case 'WAIT':
                pass

        return state

    def is_valid_end_state(state):
        return state['is_alive'] and state['end_of_lane']
    
    def is_valid_state(state):
        # print(state)
        return state['is_alive'] and state['turn'] < 5
    
    
    def backtracking(state, sequence_of_actions):
        
        if is_valid_end_state(state):
            valid_sequences_of_actions.append(sequence_of_actions)
            return 
        
        print(sequence_of_actions)
        for action in actions:
            sequence_of_actions.append(action)
            updated_state = update_state(state, action).copy()

            if is_valid_state(updated_state):
                backtracking(updated_state, sequence_of_actions)

            sequence_of_actions.pop()

    backtracking(initial_state, [])
        
    return valid_sequences_of_actions

# %%
findValidSequences(initial_state)
# Out:
# []
# ['SPEED']
# ['SPEED', 'SPEED']
# ['SPEED', 'SPEED', 'SPEED']
# ['SPEED', 'JUMP']
# ['SPEED', 'JUMP', 'SPEED']
# MOTORCYCLE MADE IT
# MOTORCYCLE MADE IT
# MOTORCYCLE MADE IT
# MOTORCYCLE MADE IT
# MOTORCYCLE MADE IT
# MOTORCYCLE MADE IT
# MOTORCYCLE MADE IT
# ['SPEED', 'SLOW']
# MOTORCYCLE MADE IT
# MOTORCYCLE MADE IT
# MOTORCYCLE MADE IT
# ['JUMP']
# ['JUMP', 'SPEED']
# ['SLOW']
# ['SLOW', 'SPEED']
# ['WAIT']
# []

# %%
print(vals)
# Out:
# []
